# %%
# !git init
# !git remote add origin https://github.com/pankajvshnv/Data-Science.git
# !git branch -M main
# !git add .
# !git commit -m "Plotting Charts using Matplotlib"
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /Users/pankajvshnv/data_science/.git/
# error: remote origin already exists.
# [main 03cde7a] Plotting Charts using Matplotlib
#  4 files changed, 8500 insertions(+), 231 deletions(-)
#  create mode 100644 .ipynb_checkpoints/Matplotlib_ Visualization-checkpoint.ipynb
#  create mode 100644 Matplotlib_ Visualization.ipynb
#  create mode 100644 popular_cities_weather.csv
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 92.17 KiB | 5.12 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/pankajvshnv/Data-Science.git
#    45f7367..03cde7a  main -> main
# branch 'main' set up to track 'origin/main'.
