# %%
# !git init
# !git remote add origin https://github.com/pankajvshnv/Data-Science.git
# !git branch -M main
# !git add .
# !git commit -m "Distribution of User Age: Skewed Toward 25-35 Demographic"
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /Users/pankajvshnv/data_science/.git/
# error: remote origin already exists.
# [main 6932d59] Distribution of User Age: Skewed Toward 25-35 Demographic
#  3 files changed, 856 insertions(+), 213 deletions(-)
#  delete mode 100644 .ipynb_checkpoints/Matplotlib_ Visualization-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Matplotlib_Visualization-checkpoint.ipynb
#  rename Matplotlib_ Visualization.ipynb => Matplotlib_Visualization.ipynb (89%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 171.41 KiB | 17.14 MiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/pankajvshnv/Data-Science.git
#    b9afd1c..6932d59  main -> main
# branch 'main' set up to track 'origin/main'.

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import random
x = random.sample(range(20,30),5)
y = random.sample(range(5,15),5)
(x,y)
# Out:
# ([22, 23, 26, 28, 25], [9, 13, 11, 12, 7])

# %%
plt.plot([x,y])
plt.show()

# %%
plt.plot([1,2,3,4,5], [2,4,3,1,10])

# %%
import numpy as np 

x = np.linspace(0,10,11)
y=x**2

# %%
plt.plot(x,y)
plt.plot(x,y)

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs, "r")
plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs, "r")
plt.xlabel("runs")
plt.ylabel("years")
plt.title("schin Tendulkar's yearly Runs")

plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs, "r")
plt.xlabel("runs")
plt.ylabel("years")
plt.title("schin Tendulkar's yearly Runs")

plt.show()

# %%
import random 
virat = random.sample(range(0,100),10)
csk = random.sample(range(0,100),10)
print(virat)
print(sck)
# Out:
# [0, 40, 68, 25, 92, 39, 33, 32, 59, 49]
# [52, 64, 16, 61, 26, 20, 31, 74, 1, 2]

# %%
import matplotlib.pyplot as plt
import random as rd

# %%
x = rd.sample(range(10,20),10)

# %%
x
# Out:
# [13, 15, 18, 14, 12, 16, 11, 10, 17, 19]

# %%
import matplotlib.pyplot as plt
import random
x = random.sample(range(20,30),5)
y = random.sample(range(5,15),5)
(x,y)
# Out:
# ([22, 24, 23, 26, 29], [8, 5, 13, 14, 9])

# %%
plt.plot(x,y)

# %%
plt.plot(
