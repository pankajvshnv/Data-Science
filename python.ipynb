# %%
# !git add .
# !git commit -m "ehduhd"
# !git push
# Out:
# [main e07b328] ehduhd
#  1 file changed, 388 insertions(+), 136 deletions(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.45 KiB | 2.45 MiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/pankajvshnv/Data-Science.git
#    64ed8c7..e07b328  main -> main

# %%
# 3. Create a clean commit for your work
# !git commit -m "Stack plots in Matplotlib"

# 4. Force push to overwrite the remote repository with your local code
# !git push origin main --force
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
print("hello", end=" end here")
# Out:
# hello end here

# %%
print("hello \nguys")
# Out:
# hello
# guys

# %%
name = "pankaj"
age = 24
print(f"my name is {name } and my age was {age +1 }.")
# Out:
# my name is pankaj and my age was 25.

# %%
name = "pankaj"
age = 30 
print(F"my name is {name + " Welcome"} and my age was {age +1 }.")
# Out:
# my name is pankaj Welcome and my age was 31.

# %%
name = "Avni" 
age = 30
address = "101"
print (f" Hello {name} your age is {age} and your address is {address}")
# Out:
#  Hello Avni your age is 30 and your address is 101

# %%
name = "deepika"
age = "30"
print('age is {}'.format(age))
# Out:
# age is 30

# %%
name = "pankaj"
age = "30"
print('{} is and age {} ' .format(name, age))
# Out:
# pankaj is and age 30

# %%
name, age = input("enter name and age")
print(name)
print(age)

# %%
name, address = input("Enter Name and Address : ").split(",")
print("Name is",name)
print("Address is",address)

# %%
id, name, address = input("Enter Id, Name and Address : ").split("maxsplit=2")
print("Name is ",name)
print("Address is ",address)
print("ID is ",id)

# %%
currect_age = 23
print(f"your age will be in nexr year is {currect_age+1}")
# Out:
# your age will be in nexr year is 24

# %%
data = input("enter you all marks by coma").split(",")
data
# Out:
# enter you all marks by coma 222,22,2,2,2,22,223221
# ['222', '22', '2', '2', '2', '22', '223221']

# %%
data.split(""
# Out:
# ['222', '22', '2', '2', '2', '22', '223221']

# %%
data[:-1]
# Out:
# ['222', '22', '2', '2', '2', '22']

# %%
a = 0b1011
print(type(a))
# Out:
# <class 'int'>

# %%
print(bin(15))
print(oct(15))
print(hex(15))
# Out:
# 0b1111
# 0o17
# 0xf

# %%
f=123_456.12_3456

type(f)
# Out:
# float

# %%
print(f)
# Out:
# 123456.123456

# %%
x = 5/2
print(x)

type(x)
# Out:
# 2.5
# float

# %%
z = 3+4j
print(z)
# Out:
# (3+4j)

# %%
x = complex(input("Enter the Complex value"))

print (x.real)
print (x.imag)
# Out:
# Enter the Complex value 2
# 2.0
# 0.0

# %%
print(True +True)
print(False+True)
print(True +True+True%3)
# Out:
# 2
# 1
# 3

# %%
import sys
name = "pankaj"
age = 23

print(sys.getsizeof(age))
# Out:
# 28

# %%
f
# Out:
# 123456.123456

# %%
x = True
y = True
z = 'true'
print (id(x))
print (id(y))
print (id(z))
# Out:
# 4303533208
# 4303533208
# 4303604960

# %%
a = 10
b = 20.1
a+b
# Out:
# 30.1

# %%
type(a)
type(b)
type(a+b)
# Out:
# float

# %%
type(a+b)
# Out:
# float

# %%
a = int(345678.345678)
b = 22

# %%
a = str(23)

b = 34

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
x = None


print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# - **+** Addition
# - **-** Subtraction
# - *****  Multiplication
# - **/**  Division
# - **//**  Floor Division
# - **%** Modulus
# - ****** Exponential

# %%
arr = 1, 21, 323, 433, 43224, 432
name= "pankaj", "mohit", "gunda", "mawali"

# %%
print(name, end=" \n hello this is the name of all condinate who is late")
# Out:
# ('pankaj', 'mohit', 'gunda', 'mawali')
#  hello this is the name of all condinate who is late

# %%
1. Student Result System
Given marks for 5 subjects:

name = "Rahul"
marks = [78, 85, 91, 67, 88]

Calculate:

Total marks
Average

Percentage
Highest mark
Lowest mark
Output something like:

Student: Rahul
Total: 409/500
Average: 81.80
Highest: 91
Lowest: 67

# %%
marks = [78, 85, 91, 67, 88]

total = 0

for mark in marks:
    total = (total + mark)

Average= ( total/len(marks))

Percentage = (total /500)*100

Lowest_mark = min(marks)
Highest_mark=  max(marks)
    
print(f"the total marks of a student is {total}")
print(f"the total marks of a Average is {Average}")
print(f"the total marks of a Percentage is {Percentage}%")

print(f"the total marks of a Highest mark is {Highest_mark}")
print(f"the total marks of a Lowest mark is {Lowest_mark}")
# Out:
# the total marks of a student is 409
# the total marks of a Average is 81.8
# the total marks of a Percentage is 81.8%
# the total marks of a Highest mark is 91
# the total marks of a Lowest mark is 67

# %%
Question 2: Shopping Cart
You have:

items = ["Keyboard", "Mouse", "USB Cable"]
prices = [1200, 700, 300]
quantities = [1, 2, 3]

Your task is to calculate the total cost of each item.

Keyboard × 1 = ₹1200
Mouse × 2 = ₹1400
USB Cable × 3 = ₹900

Then calculate the final bill:

Total Bill = ₹3500

Your tasks
Use a for loop.
Calculate price × quantity.
Print each item's cost using an f-string.
Calculate the final total.

items = ["Keyboard", "Mouse", "USB Cable"]
prices = [1200, 700, 300]
quantities = [1, 2, 3]

total = 0

Now try to complete it yourself. 💪

Send me your code when you're done, and I'll check it without giving you the solution first.

# %%
prices = [1200, 700, 300]

t_prices = 0

for i in prices:
    t_prices = t_prices +i

prices

print(t_prices)
# Out:
# 2200

# %%
items = ["Keyboard", "Mouse", "USB Cable"]
prices = [1200, 700, 300]
quantities = [1, 2, 3]

total=0
for i in range(len(items)):
    t_prices = prices[i]* quantities[i]
    print(f"{items[i]} {quantities[i]} = {t_prices}")
    total = total+ t_prices

print(total)
# Out:
# Keyboard 1 = 1200
# Mouse 2 = 1400
# USB Cable 3 = 900
# 3500

# %%
numbers = [12, 7, 25, 18, 40, 33, 16, 9, 22]

for i in numbers:
    if (i % 2) == 0:
        print("even")
    else:
        print("odd")
# Out:
# even
# odd
# odd
# even
# even
# odd
# even
# odd
# even

# %%
numbers = [10, 25, 37, 42, 56, 71, 89]
target = 100

for i in numbers:
    if i==target:
        print(f"{target} found")
        break
else:
    print(f"{target},not found")
# Out:
# 100,not found

# %%
numbers = [2, 5, 2, 8, 5, 2, 9, 8]
target = 2
]

# %%
numbers = [2, 5, 2, 8, 5, 2, 9, 8]
target = 2

count =0
for i in numbers:
    if i == target:
        count = count +1

print(count)
# Out:
# 3

# %%
numbers = [12, 45, 7, 89, 34, 67, 23]

largest = numbers[0]

for i in numbers:
    if i > largest:
        largest = i



print(largest)
# Out:
# 89

# %%
numbers = [12, 45, 7, 89, 34, 67, 23]

largest = numbers[0]

for number in numbers:
    if number < largest:
        smallest = number

print(smallest)
# Out:
# 7

# %%
num = [10, 20, 30, 40, 50]

reverse=[0]

for i in range(len(num)-1, -1, -1):
    print(i)
#     reverse.append(num[i])
# print(reverse)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
numbers = [10, -5, 0, 7, -3, 0, 15, -8, 4]

positive=0
negative=0
zero = 0

for i in numbers:
    if i > 0:
       positive= positive+1
    if i < 0:
       numbers = [12, 7, 25, 18, 40, 33, 16, 9, 22]

    if i == 0:
        zero = zero+1
print(positive)
print(negative)
print(zero)
# Out:
# 4
# 3
# 2

# %%
numbers = [12, 7, 25, 18, 40, 33, 16, 9, 22]

positive_nums =[]
for i in numbers:
    if i%2==0:
        positive_nums.append(i)
        
print(positive_nums)
# Out:
# [12, 18, 40, 16, 22]

# %%
numbers = [10, 45, 23, 89, 67, 34, 89, 12]

largest =numbers[0]
second_largest = largest[0]

for i in numbers:
    if  i > largest:
        largest = i

print(largest)
# Out:
# 89

# %%
# numbers = [10, 45, 23, 89, 67, 34, 89, 12]


numbers.sort()
print(numbers)
print(numbers[-1])
print(numbers[-2])

# print(f"the largest numner is {(largest)-1}")
# Out:
# [10, 12, 23, 34, 45, 67, 89, 89]
# 89
# 89

# %%
numbers = [5, 8, 5, 2, 8, 9, 2, 5]

seen = []
duplicates = []

for i in numbers:
    if i in seen:
        if i not in duplicates:
            duplicates.append(i)
    else:
        seen.append(i)

print(duplicates)
# Out:
# [5, 8, 2]

# %%
numbers = [1, 2, 3, 4, 6, 7, 8, 9, 10]

# %%
for i in numbers:
    i +1=

# %%
numbers = [1, 2, 3, 4, 6, 7, 8, 9, 10]

total = 0

for i in numbers:
    total += i

expected_total = 0

for i in range(1, 11):
    expected_total += i

missing = expected_total - total

print("Missing number:", missing)
# Out:
# Missing number: 5

# %%
numbers = [0, 5, 0, 3, 8, 0, 2, 7]

non_zero=[]
zero=[]

for i in numbers:
    if i ==0:
        zero.append(i)
    else:
        non_zero.append(i)

print(non_zero+zero)
# Out:
# [5, 3, 8, 2, 7, 0, 0, 0]

# %%
numbers = [2, 7, 11, ]
target = 9

for i in numbers:
    for j in numbers:
        if i + j == target:
            print(i, j)
# Out:
# 2 7
# 7 2

# %%
numbers = [4, 7, 2, 7, 9, 2, 5]
seen=[]

for i in numbers:
    if i in seen:
        print("number",i)
        break
    else:
        seen.append(i)
# Out:
# number 7

# %%
numbers = [5, -2, 8, -7, 3, -4, 9, -1]
numbers.sort()
nagative=[]
positive=[]


for i in numbers:
    if i > 0:
        positive.append(i)
    else:
        nagative.append(i)

print(nagative+positive)
# Out:
# [-7, -4, -2, -1, 3, 5, 8, 9]

# %%
numbers = [12, 5, 20, 8, 15, 3]

largest=numbers[0]
smallest=numbers[0]

for i in numbers:
    if i > largest:word = "python"
        largest = i
        
for i in numbers:
    if i < smallest:
        smallest =i
        
print(f"largest:- {largest}")
print(f"smallest:- {smallest}")
print(f"diff:{largest-smallest}")
# Out:
# largest:- 20
# smallest:- 3
# diff:17

# %%
# Count Numbers Greater Than Average
numbers = [10, 20, 30, 40, 50]

count=0
total=0

no_count=len(numbers)
for i in numbers:
    total = total+i
    
avg=total/no_count

for i in numbers:
    if i>avg:
        count=count+1

print(avg)
print(count)
# Out:
# 30.0
# 2

# %%
numbers = [12, 45, 7, 89, 34, 67, 23]

# %%
word = "pankaj"
reverse=""

for i in word:
    reverse = i+reverse
reverse
# Out:
# 'jaknap'

# %% [markdown]
# Check if a String is a Palindrome

# %%
word='pop'

reverse=''

for i in word:
    reverse = i + reverse

if reverse==word:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
# Count Vowels

word = "programming"

count=0
Consonants=0
v=("a", "e", "i", "o", "u")


for i in word:
    if i in v:
        count= count+1
Consonants= len(word)-count




print(count)
print(Consonants)
# Out:
# 3
# 8

# %%
num = [12, 7, 5, 18, 20, 33, 42, 9]
even = []
odd = []


for i in num:
    if i % 2==0:
        even.append(i)
    else:
        odd.append(i)


print(even)
print(odd)
# Out:
# [12, 18, 20, 42]
# [7, 5, 33, 9]

# %%
numbers = [5, 8, 3, 8, 2, 8, 9, 4]
target = 8
new_number=[]

for i in numbers:
    if i != target:
        new_number.append(i)

print(new_number)
# Out:
# [5, 3, 2, 9, 4]

# %%
numbers = [10, 25, 7, 40, 15, 30]

giv e

# %%
nums = [2,7,11,15]
target = 9

for i in nums:
    for j in nums:
        if i + j== target:
            print(i,j)
# Out:
# 2 7
# 7 2

# %%
numbers = [1, 2, 3, 2, 4, 5, 6, 1]

        


# for i in range(len(nums):
#     for j in range(len(nums):
#         if i + j ==target:
#             return(index
# Out:
# 0 1

# %%
numbers = [1, 2, 3, 2, 4, 5, 6, 1]

currect = 1
longest = 1

# %%
numbers = [1, 2, 3, 2, 4, 5, 6, 1]

for i in range(1, len
# Out:
# 1

# %%
numbers = [1, 2, 3, 2, 4, 5, 6, 1]

largest = numbers[0]

for i in numbers:
    if i > largest:
        largest = i

largest
# Out:
# 6

# %%
numbers = [1, 2, 3, 2, 4, 5, 6, 1]

numbers.sort()

numbers(len(-1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 numbers = [1, 2, 3, 2, 4, 5, 6, 1]
#       3 numbers.sort()
# ----> 5 numbers(len(-1))
#
# TypeError: object of type 'int' has no len()

# %%
Find the second largest element

# %%
def get_second_largest(nums):
    if len(nums) < 2:
        return None  # A list must have at least two elements

    largest = second_largest = float('-inf')
    
    for num in nums:
        if num > largest:
            second_largest = largest
            largest = num
        elif num > second_largest and num != largest:
            second_largest = num
            
    return second_largest if second_largest != float('-inf') else None

# Example usage:
numbers = [10, 20, 4, 45, 45, 99, 99, 4]
print(get_second_largest(numbers))  # Output: 45
# Out:
# 45

# %%
def greeting(name):
    print(f"hello, Good Morning {name}")

greeting("Rahul")
# Out:
# hello, Good Morning Rahul

# %%
greeting("Rahul")
# Out:
# hello, Good Morning Rahul

# %%
def get_second_largest(numbers):
    largest = numbers[0]
    second_largest = numbers[0]

    for i in numbers:
        if i > largest:
            second_largest = largest
            largest = numbers
        elif numbers > second_largest and numbers != largest:
            second_largest = numberses

    return second_largest


numbers = [10, 20, 4, 45, 45, 99, 99, 4]

print(get_second_largest(numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 17
#      12     return second_largest
#      15 numbers = [10, 20, 4, 45, 45, 99, 99, 4]
# ---> 17 print(get_second_largest(numbers))
#
# Cell In[25], line 9, in get_second_largest(numbers)
#       7         second_largest = largest
#       8         largest = numbers
# ----> 9     elif numbers > second_largest and numbers != largest:
#      10         second_largest = numberses
#      12 return second_largest
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
def arr_reverse(numbers):
    reverse =[]

    for i in numbers:
        reverse.append(i)

numbers=[23,42,23,22]
print(arr_reverse(numbers))
# Out:
# None

# %%
def larg_small(numbers):
    largest = numbers[0]
    smallest = numbers[0]

    for i in numbers:
        if i > largest:
            i = largest


numbers=[23,322,322,32,312,41,32,1321,411444]
print(larg_small(numbers))
# Out:
# None

# %%
# Find the largest and smallest element in an array.

def larg_small(numbers):

    largest=numbers[0]
    smallest=numbers[0]
    
    for i in numbers:
        if i > largest:
            largest = i

        if i < smallest:
            smallest = i

    return largest,smallest
            


numbers=[244,3332,422,23,322,222,143]
print(larg_small(numbers))
# Out:
# (3332, 23)

# %%
def sec_large(nums):
    
    nums.sort()
    
    return nums[-2]
    
nums=[23,322,4333,2221,222,222221]
print(sec_large(nums))
print(nums)
# Out:
# 4333
# [23, 222, 322, 2221, 4333, 222221]

# %%
nums = 8574
for i in str(nums):
    print(i)
# Out:
# 8
# 5
# 7
# 4

# %%
nums = 8574

while nums > 0:
    digit = nums % 10
    print(digit)
    nums //= 10

# %% [markdown]
# ## palindrome - Part 11

# %%
# plalindrome
n = 1234
num = n
result = 0

while num > 0:
    last_digit = num%10
    result=(result*10)+last_digit
    num = num//10

if n ==result:
  print("palindrome")
else:
  print(f'{n}, is not a palindrome')
    
import math
print(math.log10(n))

# %% [markdown]
# ## Armstrong Number Explained - Part 12
# num = 153
#
# 153 = 1^3 + 5^3 + 3^3
#     = 153
# the number is Armstrong

# %%
n = 153
num = n
count = len(str(num))


while num > 0:
    last_digit = num%10
    result = result+(last_digit**count )
    num = num//10

# %% [markdown]
# ## print factors / Divisors - Part 13

# %%
# Brute force 

num = 10
result=[]
for i in range(1, num+1):
    if num % i ==0:
        result.append(i)
    
print(result)
    
# count =0


# while num >0:
#     count = count +1
#     if num % count ==0:
#         print(count)
# Out:
# [1, 2, 5, 10]

# %% [markdown]
# ## Frequenct map Distionary - Part 13

# %%
frequency = dict()
# frequency={}
num=[6,5,4,3,2,4,5,6,7,8,9,0,9]


for i in range(0, len(num)):
    if num[i] in frequency:
        frequency[num[i]]=  frequency[num[i]]+1

    else:
        frequency[num[i]]=1
        
frequency
print(frequency[5])
# Out:
# 2

# %% [markdown]
# ## Second Largest Element - Part 14

# %%
def second_large(arr):
    largest = arr[0]
    second_large = arr[0]

    for i in arr:
        if i > largest:
           largest =i

        
arr= [342,422,42,4533]
print(second_large(arr))
# Out:
# None

# %%
# nums = [2, 7, 11, 15]
# target = 9


# for i in range(len(nums)):
#     for j in nums:
#         if i+j==target:
#             print(f'{i},{j}')


nums = [2, 7, 11, 15]
target = 17


for i in range(len(nums)):
    for j in range(i+1,len(nums)):
        if nums[i]+nums[j]==target:
            print(f'{i},{j}')

# %% [markdown]
# ## recursion therory - Part 15

# %%
# PRINT PANKAJ 4 TIMES
## head tracking time 
# complecity O(N+1)  0(N)
# space complecity O(n+1) o(N)
def print_name(count):
    if count ==4:
        return 

    print("panakj")
    count = count +1
    print_name(count)

print_name(count)
# Out:
# panakj
# panakj
# panakj
# panakj

# %% [markdown]
# #### tail recursion/backtracking

# %%
# print name 4 time

count =0
def fun():
    if count ==4:
        return
        
    count = count+1
    fun()
    print("panakj")

# %%
# recursing using paramters
# print x, n times

# x = 7
# n = 5

def func(x,n):
    if n ==0:
        return
    print(x)
    func(x,n-1)

# %%
func(7,5)
# Out:
# 7
# 7
# 7
# 7
# 7

# %%
# print 1 to n using Head rcurtsion 


def counting_head(x,n):
    if x > n:
        return

    print(x)
    counting(x+1,n)


# print 1 to n using tail recurtion
    

def counting_tail(x,n):
    if x > n:
        return

    
    counting_tail(x+1,n)
    print(x)

n =10
def counting_tail_opti(n):
    if n==0:
        return
    print(n)
    counting_tail_opti(n-1)

# %% [markdown]
# ## factorail of a number

# %%
# x = 5
# 5x4x3x2x1x1


def fac(num):
    if num == 0 or num ==1:
        return 1

    return num *fac(num-1)

# %%
fac(5)
# Out:
# 120

# %% [markdown]
# ## Reverse an array using Recursion - Part 16

# %%
num = [1,2,3,4,5]

L = 0
R = len(num)-1 

num[L],num[R]=num[R],num[L]


def func(nums, L, R):
    if L==R:
        return
    num[L],num[R]=num[R],num[L]
    func(num, L+1, R-1)
    
func(num, L, R)

# %%
# index# 0 1 2 3 4 5 6
arr = [1,2,3,4,5,6,7]
left = 0
right = len(arr)-1


def reserve_array(arr, left, right):
    if right >= left:
        return

    arr[left],arr[right]=arr[right],arr[left]
    reserve_array(arr, left+1, right-1)


reserve_array(arr, 0, len(arr)-1)

print(arr)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
arr = [1, 2, 3, 4, 5, 6, 7]

def reverse_array(arr, left, right):
    if left >= right:
        return

    arr[left], arr[right] = arr[right], arr[left]
    reverse_array(arr, left + 1, right - 1)

reverse_array(arr, 0, len(arr) - 1)


# def array(arr,1,5):
#     slef.reverse_array(arr, 1,5)
#     return arr

# %%
arr = [1, 2, 3, 4, 5, 6, 7,8]

left = 0
right = len(arr)-1


while left < right:
    arr[left], arr[right]= arr[right],arr[left]
    left = left +1
    right = right -1
        

arr
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ## Check if a String is Palindrome or Not - Part 17

# %%
left  = 0
right = len(name)-1

name = "nitin"

while left<right:
    if name[left] != name[right]:
        print(False)
        
    left = left + 1
    right = right -1
        
else:
    print(True)
# Out:
# True

# %%
name = "nituyin"
    #   0 1 2 3 4
#name = n i t i n


left = 0
right = len(name)-1

def pall_str(name, left, right):
    if name[left] != name[right]:
        return False

    name[left] == name[right]
    left = left +1
    right = right -1
    pall_str()
    return True

pall_str(name, left, right)

# %%
def func(num):
    if num == 0 or num ==1:
        return 1
    
    return num * func(num-1)

# 5 x 4 x 3 x 2 x 1 x 0 

func(5)
# Out:
# 120

# %% [markdown]
# ## Find the Fibonacci Number - Part 18

# %%
def func(num):
        if num == 0:
            return 0
        if num == 1:
            return 1

        return func( num-1 )+ func( num-2 )

# %% [markdown]
# ## Selection Sort in Python - Part 19
#
# time complexity o(n(n+2))/2 ,  o(N^2)

# %%
nums = [5, 7, 8 , 4, 1, 6, 9, 2]
       # "
     # min_index

def selection_sort(nums):
    n = len(nums)

    for i in range(0, n):

        min_index = i
        for j in range(i+1,n):
            if nums[j] < nums[min_index]:
                min_index = j
        nums[i],nums[min_index]=nums[min_index], nums[i]
            
selection_sort(nums) 
print(nums)
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]

# %%
nums = [5, 7, 8 , 4, 1, 6, 9, 2]
  # max_index


def selection_sort_dec(nums):
    n = len(nums)

    for i in range(0,n):
        max_index = i
        for j in range(i+1,n):
            if nums[j] > nums[max_index ]:
                max_index= j
                
        nums[i],nums[max_index]=nums[max_index], nums[i]
        

selection_sort_dec(nums)
print(nums)
# Out:
# [9, 8, 7, 6, 5, 4, 2, 1]

# %% [markdown]
# ## Bubble Sort in Python - Part 20
# Adjuacent swaps o(n(n+2))/2 , o(N^2)

# %%
nums= [5, 3, 8, 4, 6]
    #  j      # i(n-2)

def Bubble_sort(nums):
    n = len(nums)

    for i in range(n-2,-1,-1):
        for j in range(0,i+1):
            if nums[j]< nums[j+1]:
                nums[j],nums[j+1]=nums[j+1],nums[j]
            
    
Bubble_sort(nums)
print(nums)
# Out:
# [8, 6, 5, 4, 3]

# %% [markdown]
# ## Insertion Sort in Python - Part 21
