# %%
import pandas as pd
data= pd.read_csv("housing.csv")

# %%
import numpy as np
data["income_cat"]=pd.cut(data["median_income"], bins=[0, 1.5, 3.0, 4.5, 6.0, np.inf],labels=[1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Assume income_cat is a column in the dataset created from median_income
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(data, data["income_cat"]):
    train_set = data.loc[train_index]
    test_set = data.loc[test_index]

# %%
df = train_set

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5
# 2908           INLAND          2
# 14053      NEAR OCEAN          2
# 20496       <1H OCEAN          3
# ...               ...        ...
# 15174       <1H OCEAN          4
# 12661          INLAND          2
# 19263       <1H OCEAN          3
# 19140       <1H OCEAN          3
# 19773          INLAND          3
#
# [16512 rows x 11 columns]

# %%
house_value = df["median_house_value"]

# %%
house_value.isnull().sum()
# Out:
# np.int64(0)

# %%
df2 =df.drop(columns=["median_house_value","income_cat"])

# %%
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income ocean_proximity
# 12655      2237.0       706.0         2.1736          INLAND
# 15502      2015.0       768.0         6.3373      NEAR OCEAN
# 2908        667.0       300.0         2.8750          INLAND
# 14053       898.0       483.0         2.2264      NEAR OCEAN
# 20496      1837.0       580.0         4.4964       <1H OCEAN
# ...           ...         ...            ...             ...
# 15174      2026.0      1001.0         5.0900       <1H OCEAN
# 12661      4769.0      1418.0         2.8139          INLAND
# 19263       458.0       172.0         3.1797       <1H OCEAN
# 19140      1208.0       501.0         4.1964       <1H OCEAN
# 19773       625.0       197.0         3.1319          INLAND
#
# [16512 rows x 9 columns]

# %%
df2.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        158
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

# %% [markdown]
# # Handling Missing Data
# Some features, like total_bedrooms, contain missing values. You can:
#
# Drop rows with missing values
# Drop the entire column
# Impute missing values (recommended)

# %% [markdown]
# # Other available strategies:
#
# "mean" – replaces with mean value
#
# "most_frequent" – for the most common value (can handle categorical)
#
# "constant" – fill with a fixed value using fill_value=...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
 
df2 = df2.select_dtypes(include=[np.number])
df3 =imputer.fit(df2)

# %%
df3
# Out:
# SimpleImputer(strategy='median')

# %% [markdown]
# # Handling Categorical values

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5
# 2908           INLAND          2
# 14053      NEAR OCEAN          2
# 20496       <1H OCEAN          3
# ...               ...        ...
# 15174       <1H OCEAN          4
# 12661          INLAND          2
# 19263       <1H OCEAN          3
# 19140       <1H OCEAN          3
# 19773          INLAND          3
#
# [16512 rows x 11 columns]

# %%
df2=df.drop(columns=['income_cat'])

# %%
set(df2[

# %%
set(df2["ocean_proximity"])
# Out:
# {'<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'}

# %% [markdown]
# # Categorical Attributes
# Text columns like "ocean_proximity" are not free-form text but limited to a fixed set of values (e.g., "NEAR BAY", "INLAND"). These are known as categorical attributes.

# %%
housing_cat = housing[["ocean_proximity"]]
housing_cat.head()

# %% [markdown]
# # 2. Ordinal Encoding
# Scikit-Learn's OrdinalEncoder can convert categories to numbers:

# %%
from sklearn.preprocessing import OrdinalEncoder
 
ordinal_encoder = OrdinalEncoder()
housing_cat_encoded = ordinal_encoder.fit_transform(df2)

# %%
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# 20496       <1H OCEAN
# ...               ...
# 15174       <1H OCEAN
# 12661          INLAND
# 19263       <1H OCEAN
# 19140       <1H OCEAN
# 19773          INLAND
#
# [16512 rows x 10 columns]

# %% [markdown]
# # 3. One-Hot Encoding
# For unordered categories, one-hot encoding is a better choice. It creates one binary column per category.

# %%
from sklearn.preprocessing import OneHotEncoder
 
cat_encoder = OneHotEncoder()
housing_cat_1hot = cat_encoder.fit_transform(ocean_proximity_data)

# %%
ocean_proximity_data = df[["ocean_proximity"]]

# %%
ocean_proximity_data
# Out:
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# 20496       <1H OCEAN
# ...               ...
# 15174       <1H OCEAN
# 12661          INLAND
# 19263       <1H OCEAN
# 19140       <1H OCEAN
# 19773          INLAND
#
# [16512 rows x 1 columns]

# %% [markdown]
# # Feature scaling in sklearn/ Normalizing Datasets in ML
# ## Feature scaling is a crucial preprocessing step. Most machine learning algorithms perform poorly when input features have vastly different scales.
#
# In the California housing dataset, for example:
#
# total_rooms ranges from 6 to over 39,000
# median_income ranges from 0 to 15
# If you don’t scale these features, models will give more importance to total_rooms simply because it has larger values.

# %%
from sklearn.preprocessing import OneHotEncoder

# Initialize the encoder (sparse_output=False returns a dense NumPy array)
cat_encoder = OneHotEncoder(sparse_output=False)

# Fit and transform the ocean_proximity column
ocean_proximity_1hot = cat_encoder.fit_transform(df[["ocean_proximity"]])

# Optional: Convert back to a pandas DataFrame with category column names
import pandas as pd

encoded_df = pd.DataFrame(
    ocean_proximity_1hot,
    columns=cat_encoder.get_feature_names_out(["ocean_proximity"]),
    index=df.index
)

encoded_df.head()
# Out:
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12655                        0.0                     1.0
# 15502                        0.0                     0.0
# 2908                         0.0                     1.0
# 14053                        0.0                     0.0
# 20496                        1.0                     0.0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12655                     0.0                       0.0
# 15502                     0.0                       0.0
# 2908                      0.0                       0.0
# 14053                     0.0                       0.0
# 20496                     0.0                       0.0
#
#        ocean_proximity_NEAR OCEAN
# 12655                         0.0
# 15502                         1.0
# 2908                          0.0
# 14053                         1.0
# 20496                         0.0

# %%
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# 20496       <1H OCEAN
# ...               ...
# 15174       <1H OCEAN
# 12661          INLAND
# 19263       <1H OCEAN
# 19140       <1H OCEAN
# 19773          INLAND
#
# [16512 rows x 10 columns]

# %%
df = pd.concat(

# %%
data=df2.drop(columns=['ocean_proximity'])

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
# [16512 rows x 9 columns]

# %%
encoded_df
# Out:
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12655                        0.0                     1.0
# 15502                        0.0                     0.0
# 2908                         0.0                     1.0
# 14053                        0.0                     0.0
# 20496                        1.0                     0.0
# ...                          ...                     ...
# 15174                        1.0                     0.0
# 12661                        0.0                     1.0
# 19263                        1.0                     0.0
# 19140                        1.0                     0.0
# 19773                        0.0                     1.0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12655                     0.0                       0.0
# 15502                     0.0                       0.0
# 2908                      0.0                       0.0
# 14053                     0.0                       0.0
# 20496                     0.0                       0.0
# ...                       ...                       ...
# 15174                     0.0                       0.0
# 12661                     0.0                       0.0
# 19263                     0.0                       0.0
# 19140                     0.0                       0.0
# 19773                     0.0                       0.0
#
#        ocean_proximity_NEAR OCEAN
# 12655                         0.0
# 15502                         1.0
# 2908                          0.0
# 14053                         1.0
# 20496                         0.0
# ...                           ...
# 15174                         0.0
# 12661                         0.0
# 19263                         0.0
# 19140                         0.0
# 19773                         0.0
#
# [16512 rows x 5 columns]

# %%
df = pd.concat([data, encoded_df], axis=1)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12655                        0.0                     1.0
# 15502                        0.0                     0.0
# 2908                         0.0                     1.0
# 14053                        0.0                     0.0
# 20496                        1.0                     0.0
# ...                          ...                     ...
# 15174                        1.0                     0.0
# 12661                        0.0                     1.0
# 19263                        1.0                     0.0
# 19140                        1.0                     0.0
# 19773                        0.0                     1.0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12655                     0.0                       0.0
# 15502                     0.0                       0.0
# 2908                      0.0                       0.0
# 14053                     0.0                       0.0
# 20496                     0.0                       0.0
# ...                       ...                       ...
# 15174                     0.0                       0.0
# 12661                     0.0                       0.0
# 19263                     0.0                       0.0
# 19140                     0.0                       0.0
# 19773                     0.0                       0.0
#
#        ocean_proximity_NEAR OCEAN
# 12655                         0.0
# 15502                         1.0
# 2908                          0.0
# 14053                         1.0
# 20496                         0.0
# ...                           ...
# 15174                         0.0
# 12661                         0.0
# 19263                         0.0
# 19140                         0.0
# 19773                         0.0
#
# [16512 rows x 14 columns]

# %% [markdown]
# # Min-Max Scaling (Normalization)
# Sensitive to outliers — extreme values can distort the scale.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
df_scaled = scaler.fit_transform(df)

# %%
df_scaled = pd.DataFrame(df_scaled, columns= df.columns, index=df.index)

# %%
df_scaled
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655  -0.424303  0.270988            0.098039    -0.803276       -0.743879
# 15502   0.418327 -0.883103           -0.764706    -0.729664       -0.725193
# 2908    0.057769 -0.398512            0.686275    -0.917994       -0.900773
# 14053   0.438247 -0.955367           -0.098039    -0.904818       -0.833441
# 20496   0.125498 -0.630181            0.019608    -0.820420       -0.792526
# ...          ...       ...                 ...          ...             ...
# 15174   0.450199 -0.895855           -0.490196    -0.661240       -0.604059
# 12661  -0.416335  0.268863           -0.450980    -0.598362       -0.542526
# 19263  -0.675299  0.253985            0.843137    -0.964338       -0.947165
# 19140  -0.671315  0.226355           -0.490196    -0.839803       -0.813789
# 19773  -0.559761  0.579171            0.019608    -0.945414       -0.929124
#
#        population  households  median_income  median_house_value  \
# 12655   -0.874772   -0.737117      -0.769148           -0.764533
# 15502   -0.887217   -0.713966      -0.194852            0.091134
# 2908    -0.962779   -0.888723      -0.672405           -0.720822
# 14053   -0.949830   -0.820388      -0.761865           -0.597936
# 20496   -0.897194   -0.784167      -0.448766           -0.079175
# ...           ...         ...            ...                 ...
# 15174   -0.886600   -0.626960      -0.366891            0.045361
# 12661   -0.732840   -0.471247      -0.680832           -0.689069
# 19263   -0.974495   -0.936520      -0.630378           -0.482885
# 19140   -0.932453   -0.813667      -0.490145            0.002474
# 19773   -0.965134   -0.927184      -0.636971           -0.803296
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12655                       -1.0                     1.0
# 15502                       -1.0                    -1.0
# 2908                        -1.0                     1.0
# 14053                       -1.0                    -1.0
# 20496                        1.0                    -1.0
# ...                          ...                     ...
# 15174                        1.0                    -1.0
# 12661                       -1.0                     1.0
# 19263                        1.0                    -1.0
# 19140                        1.0                    -1.0
# 19773                       -1.0                     1.0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12655                    -1.0                      -1.0
# 15502                    -1.0                      -1.0
# 2908                     -1.0                      -1.0
# 14053                    -1.0                      -1.0
# 20496                    -1.0                      -1.0
# ...                       ...                       ...
# 15174                    -1.0                      -1.0
# 12661                    -1.0                      -1.0
# 19263                    -1.0                      -1.0
# 19140                    -1.0                      -1.0
# 19773                    -1.0                      -1.0
#
#        ocean_proximity_NEAR OCEAN
# 12655                        -1.0
# 15502                         1.0
# 2908                         -1.0
# 14053                         1.0
# 20496                        -1.0
# ...                           ...
# 15174                        -1.0
# 12661                        -1.0
# 19263                        -1.0
# 19140                        -1.0
# 19773                        -1.0
#
# [16512 rows x 14 columns]

# %% [markdown]
# ## Standardization (Z-score Scaling)
# ###his method centers the data around 0 and scales it based on standard deviation.
#
# ###Formula: standardized_value = (x - mean) / std

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_scaled = scaler.fit_transform(df)

# %%
df_scaled = pd.DataFrame(df_scaled, columns=df.columns,  index=df.index)

# %%
df_scaled
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655  -0.941350  1.347438            0.027564     0.584777        0.635123
# 15502   1.171782 -1.192440           -1.722018     1.261467        0.775677
# 2908    0.267581 -0.125972            1.220460    -0.469773       -0.545045
# 14053   1.221738 -1.351474           -0.370069    -0.348652       -0.038567
# 20496   0.437431 -0.635818           -0.131489     0.427179        0.269198
# ...          ...       ...                 ...          ...             ...
# 15174   1.251711 -1.220505           -1.165333     1.890456        1.686854
# 12661  -0.921368  1.342761           -1.085806     2.468471        2.149712
# 19263  -1.570794  1.310018            1.538566    -0.895802       -0.894007
# 19140  -1.560803  1.249211           -1.165333     0.249005        0.109257
# 19773  -1.281050  2.025674           -0.131489    -0.721836       -0.758300
#
#        population  households  median_income  median_house_value  \
# 12655    0.732602    0.556286      -0.893647           -1.166015
# 15502    0.533612    0.721318       1.292168            0.627451
# 2908    -0.674675   -0.524407      -0.525434           -1.074397
# 14053   -0.467617   -0.037297      -0.865929           -0.816829
# 20496    0.374060    0.220898       0.325752            0.270486
# ...           ...         ...            ...                 ...
# 15174    0.543471    1.341519       0.637374            0.531511
# 12661    3.002174    2.451492      -0.557509           -1.007844
# 19263   -0.862013   -0.865118      -0.365475           -0.575684
# 19140   -0.189747    0.010616       0.168261            0.441622
# 19773   -0.712322   -0.798573      -0.390569           -1.247261
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12655                  -0.887683                 1.46218
# 15502                  -0.887683                -0.68391
# 2908                   -0.887683                 1.46218
# 14053                  -0.887683                -0.68391
# 20496                   1.126529                -0.68391
# ...                          ...                     ...
# 15174                   1.126529                -0.68391
# 12661                  -0.887683                 1.46218
# 19263                   1.126529                -0.68391
# 19140                   1.126529                -0.68391
# 19773                  -0.887683                 1.46218
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12655               -0.011006                 -0.354889
# 15502               -0.011006                 -0.354889
# 2908                -0.011006                 -0.354889
# 14053               -0.011006                 -0.354889
# 20496               -0.011006                 -0.354889
# ...                       ...                       ...
# 15174               -0.011006                 -0.354889
# 12661               -0.011006                 -0.354889
# 19263               -0.011006                 -0.354889
# 19140               -0.011006                 -0.354889
# 19773               -0.011006                 -0.354889
#
#        ocean_proximity_NEAR OCEAN
# 12655                   -0.384217
# 15502                    2.602693
# 2908                    -0.384217
# 14053                    2.602693
# 20496                   -0.384217
# ...                           ...
# 15174                   -0.384217
# 12661                   -0.384217
# 19263                   -0.384217
# 19140                   -0.384217
# 19773                   -0.384217
#
# [16512 rows x 14 columns]

# %% [markdown]
# #### Use Scikit-Learn’s StandardScaler:
# ##### Resulting features have zero mean and unit variance
# ##### Robust to outliers compared to min-max scaling
# Recommended for most ML algorithms, especially when using gradient descent

# %% [markdown]
# # Constructing Pipelines in sklearn

# %% [markdown]
# As datasets grow more complex, data preprocessing often involves multiple steps such as imputing missing values, scaling features, encoding categorical variables, etc. These steps must be applied in the correct order and consistently across training, validation, test, and future production data.
#
# To streamline this process, Scikit-Learn provides the Pipeline class — a powerful utility for chaining data transformations.

# %%
df = train_set

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5
# 2908           INLAND          2
# 14053      NEAR OCEAN          2
# 20496       <1H OCEAN          3
# ...               ...        ...
# 15174       <1H OCEAN          4
# 12661          INLAND          2
# 19263       <1H OCEAN          3
# 19140       <1H OCEAN          3
# 19773          INLAND          3
#
# [16512 rows x 11 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
mypipeline = Pipeline([
    ("impute", SimpleImputer(strategy="median")),
     ("StandardScaler", StandardScaler()),
     ])

# %%
df.head(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5

# %%
df_train=df.drop(columns=['ocean_proximity', 'income_cat'])
df_train.head(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
#
#        population  households  median_income  median_house_value
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0

# %%
Pre_data=mypipeline.fit_transform(df_train)
Pre_data_c=pd.DataFrame(df_scaled, columns= df_train.columns, index=df_train.index)

# %%
Pre_data_c
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655  -0.941350  1.347438            0.027564     0.584777        0.635123
# 15502   1.171782 -1.192440           -1.722018     1.261467        0.775677
# 2908    0.267581 -0.125972            1.220460    -0.469773       -0.545045
# 14053   1.221738 -1.351474           -0.370069    -0.348652       -0.038567
# 20496   0.437431 -0.635818           -0.131489     0.427179        0.269198
# ...          ...       ...                 ...          ...             ...
# 15174   1.251711 -1.220505           -1.165333     1.890456        1.686854
# 12661  -0.921368  1.342761           -1.085806     2.468471        2.149712
# 19263  -1.570794  1.310018            1.538566    -0.895802       -0.894007
# 19140  -1.560803  1.249211           -1.165333     0.249005        0.109257
# 19773  -1.281050  2.025674           -0.131489    -0.721836       -0.758300
#
#        population  households  median_income  median_house_value
# 12655    0.732602    0.556286      -0.893647           -1.166015
# 15502    0.533612    0.721318       1.292168            0.627451
# 2908    -0.674675   -0.524407      -0.525434           -1.074397
# 14053   -0.467617   -0.037297      -0.865929           -0.816829
# 20496    0.374060    0.220898       0.325752            0.270486
# ...           ...         ...            ...                 ...
# 15174    0.543471    1.341519       0.637374            0.531511
# 12661    3.002174    2.451492      -0.557509           -1.007844
# 19263   -0.862013   -0.865118      -0.365475           -0.575684
# 19140   -0.189747    0.010616       0.168261            0.441622
# 19773   -0.712322   -0.798573      -0.390569           -1.247261
#
# [16512 rows x 9 columns]

# %% [markdown]
# # ColumnTransformer and Consolidating the Pipeline

# %% [markdown]
# ColumnTransformer and Consolidating the Pipeline
# In this section, we will consolidate everything we've done so far into one final script using Scikit-Learn pipelines. This includes:
#
# Creating a stratified test set
# Handling missing values
# Encoding categorical variables
# Scaling numerical features
# Combining everything using Pipeline and ColumnTransformer
# This will ensure clean, modular, and reproducible code — perfect for production and education.
