# %%
import pandas as pd

# %%
from sklearn.naive_bayes import GaussianNB

# %%
data_train= pd.read_csv("iris-train.csv")
df_train.head()
# Out:
#    4.3    3  1.1  0.1      Iris-setosa
# 0  4.7  3.2  1.6  0.2      Iris-setosa
# 1  5.7    3  4.2  1.2  Iris-versicolor
# 2  5.6  2.7  4.2  1.3  Iris-versicolor
# 3  6.7  2.5  5.8  1.8   Iris-virginica
# 4  6.7  3.1  5.6  2.4   Iris-virginica

# %%
data_test=pd.read_csv("iris-test.csv")

# %%
x = data_train.iloc[:, :-1]
x.head()
# Out:
#    sepalength   sepalwidth  petallength  petalwidth
# 0          4.3         3.0          1.1         0.1
# 1          4.7         3.2          1.6         0.2
# 2          5.7         3.0          4.2         1.2
# 3          5.6         2.7          4.2         1.3
# 4          6.7         2.5          5.8         1.8

# %%
y = data_train.iloc[:, -1]
y
# Out:
# 0          Iris-setosa
# 1          Iris-setosa
# 2      Iris-versicolor
# 3      Iris-versicolor
# 4       Iris-virginica
#             ...
# 113    Iris-versicolor
# 114    Iris-versicolor
# 115     Iris-virginica
# 116     Iris-virginica
# 117        Iris-setosa
# Name: class, Length: 118, dtype: object

# %%
model = GaussianNB()

# %%
model.fit(x,y)
# Out:
# GaussianNB()

# %%
predication = model.predict([[5.4, 3, 4.5, 1.5]])
predication
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype='<U15')

# %%
data_test = pd.read_csv("iris-test.csv")
data_test.head()
# Out:
#    sepalength   sepalwidth  petallength  petalwidth            class
# 0          5.6         2.5          3.9         1.1  Iris-versicolor
# 1          6.8         3.2          5.9         2.3   Iris-virginica
# 2          6.9         3.1          5.4         2.1   Iris-virginica
# 3          5.4         3.4          1.5         0.4      Iris-setosa
# 4          5.6         2.8          4.9         2.0   Iris-virginica

# %%
x_test = data_test.iloc[:, :-1]

# %%
predictions = model.predict(x_test.values)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa'], dtype='<U15')

# %% [markdown]
# # accuracy_iris

# %%
data_test.head()
# Out:
#    sepalength   sepalwidth  petallength  petalwidth            class
# 0          5.6         2.5          3.9         1.1  Iris-versicolor
# 1          6.8         3.2          5.9         2.3   Iris-virginica
# 2          6.9         3.1          5.4         2.1   Iris-virginica
# 3          5.4         3.4          1.5         0.4      Iris-setosa
# 4          5.6         2.8          4.9         2.0   Iris-virginica

# %%
x_test = data_test.iloc[:, :-1]

# %%
y_test= data_test.iloc[:, -1]
y_test.head()
# Out:
# 0    Iris-versicolor
# 1     Iris-virginica
# 2     Iris-virginica
# 3        Iris-setosa
# 4     Iris-virginica
# Name: class, dtype: object

# %%
actual = y_test.values
actual
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
count = 0
for i in range(0, len(actual)):
    if actual[i] == predictions[i]:
        count = count+1
print(count* 100/len(actual))
# Out:
# 96.875

# %%
96.875
# Out:
# 96.875

# %% [markdown]
# # RMSE and MAE

# %% [markdown]
# # Analyzing the Data (EDA)

# %%
import pandas as pd

# %%
data= pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.hist(bins=50, figsize=(15,20))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data= pd.read_csv("housing.csv")

# %%
import pandas as pd

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import numpy as np

# %%
def shuffle_and_split(data, test_ratio):

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# 1. Generate a mock dataset (100 rows, 3 features, 1 binary target)
np.random.seed(42)
X_data = np.random.rand(100, 3)
y_data = np.random.choice([0, 1], size=100)

# Create a DataFrame for scannability
df = pd.DataFrame(X_data, columns=['Feature_1', 'Feature_2', 'Feature_3'])
df['Target'] = y_data

# 2. Extract features (X) and target variable (y)
X = df.drop(columns=['Target'])
y = df['Target']

# 3. Create the split (80% training, 20% test set)
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.20,       # Reserves 20% of the data for the test set
    random_state=42,      # Ensures the split is completely reproducible
    shuffle=True,         # Mixes data to eliminate order-based bias
    stratify=y            # Maintains identical class proportions in both sets
)

# Verify the resulting matrix sizes
print(f"Full dataset shape: {df.shape}")
print(f"Training features shape: {X_train.shape} | Test features shape: {X_test.shape}")
print(f"Training target distribution:\n{y_train.value_counts(normalize=True)}")
# Out:
# Full dataset shape: (100, 4)
# Training features shape: (80, 3) | Test features shape: (20, 3)
# Training target distribution:
# Target
# 1    0.5375
# 0    0.4625
# Name: proportion, dtype: float64

# %% [markdown]
# # Stratified Shuffle Split

# %% [markdown]
# When building machine learning models, one of the most important steps is splitting your dataset into training and test sets. This ensures your model is evaluated on data it has never seen before, which is critical for assessing its ability to generalize.
#
# The Problem of Data Snooping Bias
# Data snooping bias occurs when information from the test set leaks into the training process. This can lead to overly optimistic performance metrics and models that don’t perform well in real-world scenarios.
#
# To avoid this, the test set must be isolated before any data exploration, feature selection, or model training begins.

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data["income_cat"]=pd.cut(data["median_income"], bins=[0, 1.5, 3.0, 4.5, 6.0, np.inf],labels=[1, 2, 3, 4, 5])

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
data["income_cat"].value_counts().plot.bar()
plt.title("income categories distribution")
plt.xlabel("Income Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Stratified Shuffle Split in Scikit-Learn

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Assume income_cat is a column in the dataset created from median_income
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(data, data["income_cat"]):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
strat_train_set["income_cat"].value_counts().plot.bar()
plt.title("income categories distribution")
plt.xlabel("Income Category")
plt.ylabel("Count")
plt.show()

# %%
strat_test_set["income_cat"].value_counts().plot.bar()
plt.title("income categories distribution")
plt.xlabel("Income Category")
plt.ylabel("Count")
plt.show()
